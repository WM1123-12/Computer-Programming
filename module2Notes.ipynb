# %% [markdown]
# #### Module 2 notes: Lists

# %%
fav_words = ["potato", "serundipitous", "dubious"]
print(fav_words)
print(fav_words[0])
print(fav_words[2])
print(fav_words[-1].upper())
print(fav_words[1].title())
print("One of my favorite words is:", fav_words[0])
sentence = f"One of my favorite words is: {fav_words[0]}"
print(sentence)
print(len(fav_words))

print(f"I {fav_words[1]} ate {len(fav_words)} {fav_words[2]} {fav_words[0]}")
# Out:
# ['potato', 'serundipitous', 'dubious']
# potato
# dubious
# DUBIOUS
# Serundipitous
# One of my favorite words is: potato
# One of my favorite words is: potato
# 3
# I serundipitous ate 3 dubious potato

# %% [markdown]
# #### every item in a list has a location starting at 0. we can also strat form the end with -1. the locaton is referred to as an index. the first item in a list is at inex 0. we can use the items in the list as is appropriate according to their type. the way we access them is name_of_list[index]. we can also use a len function that tells us how long out list is.

# %%
my_birthday = ["June", "first", 2010]
birthday_statement = f"I was born in the year {my_birthday[2]}, on the {my_birthday[1]}, and on the month {my_birthday[0]}"
print(birthday_statement)
# Out:
# I was born in the year 2010, on the first, and on the month June

# %%
list_of_siblings = ["Rosie", "Bartholomew", "Richard", "Abraham"]
list_of_siblings[1] = "James"
siblings_ranking = f"I like {list_of_siblings[1]} the most, {list_of_siblings[3]} the second most, {list_of_siblings[0]} the third most, and {list_of_siblings[2]} the least."
print(siblings_ranking)
# Out:
# I like James the most, Abraham the second most, Rosie the third most, and Richard the least.

# %%
grades = [75, 81, 93, 85, 65]
print((grades[0]+grades[1]+grades[2]+grades[3]+grades[4])/len(grades))
# Out:
# 79.8
