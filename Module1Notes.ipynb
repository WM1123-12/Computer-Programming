# %%
X = 1
Y = 1.1
Z = "Cat"
print(X)
print(Y)
print(Z)
# Out:
# 1
# 1.1
# Cat

# %% [markdown]
# #### I created 3 variables named X, Y, and Z, where X is an integer, Y is a float, and Z is a string
# #### I used the print command to print them

# %%
jar1 = 5
jar2 = 10
hello = "hello"
print(jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 jar1 = 5
#       2 jar2 = 10
#       3 hello = "hello"
# ----> 4 print(jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### This code failed because you cant add strings to integers

# %%
jar1 = 5
jar2 = 10
print(jar2)

jar2 = jar1
print(jar2)
# Out:
# 10
# 5

# %% [markdown]
# #### the value to the left of the = sign get set to the value on the right side

# %%
name = "John"
age = 8
print("My name is",name,"and I am",age,"years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# #### When i am printing multiple things like strings, literals, and avariables all at once, i use commas to separate them int he print statement

# %%
myName = "William"
print(myName.upper())
print(myName.lower())
# Out:
# WILLIAM
# william

# %% [markdown]
# #### print is a function. it can be used by itself and you can put what you want to print in the parenthesis
# #### .upper() is a method, you can use it on a string that you want all the letters to be in upper case

# %%
my_life = "the life of william"
print(my_life.title())
# Out:
# The Life Of William

# %%
first_name = "William"
last_name = "Meares"
full_name = f"{first_name} {last_name}"
print(f"Hello, {full_name.title()}!")
# Out:
# Hello, William Meares!

# %% [markdown]
# #### this turns two variables that are strings into one variable with both variables in it to make one string. you can combine multiple aspects into one peice of code. if refering to an entity, use curly braces

# %%
print("Grocery list: \n\tapples \nmilk \n\tpeanut \nbutter \n\tbananas")
# Out:
# Grocery list:
# 	apples
# milk
# 	peanut
# butter
# 	bananas

# %% [markdown]
# #### you can create new lines between words with \n and you can indent lines with \t
